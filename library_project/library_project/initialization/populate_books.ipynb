# %%
from collections import Counter
a = (('',), ('"O\'Reilly Media, Inc."',), ('Llewellyn Worldwide',), ('Red Deer Press',), ('Hachette Digital, Inc.',), ('Penguin',), ('David C Cook',), ('Routledge',), ('Lee Resources, Inc.',), ('John Wiley & Sons',), ('AAA',), ('Simon and Schuster',), ('Hippocrene Books',), ('Weiser Books',), ('Chartwell Books',), ('OUP Oxford',), ('Avon',), ("Frances Lincoln Children's Books",), ('Peppa Pig',), ('Booksurge Publishing',), ('Charles C Thomas Publisher',), ('Infinity Pub',), ('Canongate Books',), ('Independently Published',), ('Cambridge University Press',), ('Chronicle Books Llc',), ('Courier Corporation',), ('Lily Zante',), ('Knopf',), ('Paulist Press',), ('Harper Collins',), ('University of Toronto Press',), ('Simon & Schuster/Paula Wiseman Books',), ('Pantheon',), ('BenBella Books, Inc.',), ('EquiLibrium Press',), ('Sourcebooks Jabberwocky',), ('Zebra Books',), ('Jessica Kingsley Publishers',), ('HarperCollins UK',), ('Drawn and Quarterly',), ('Wiley',), ('Prentice Hall',), ('Que Pub',), ('John Wiley & Sons Incorporated',), ('Berkley Publishing Group',), ('Zondervan',), ('Rotovision',), ('BRILL',), ('Atria Books',), ('DARcorporation',), ('McFarland',), ('Classic Good Books',), ('Hal Leonard Corporation',), ('Hachette UK',), ('Canelo',), ('August House Pub Incorporated',), ('Hendrickson Publishers',), ('UNC Press Books',), ('Dramatists Play Service Inc',), ('Conari Press',), ('Good Press',), ('A&C Black',), ('Bulfinch Press',), ('Kent State University Press',), ('IGI Global',), ('Turtleback',), ('Berkley',), ('Walter Foster Pub',), ('Unwin Hyman',), ('Princeton University Press',), ('Open Road Media Sci-Fi & Fantasy',), ('Elsevier Health Sciences',), ('HMH Books For Young Readers',), ('Prometheus',), ('Cisco Press',), ('Charlesbridge Publishing',), ('Open Road Media',), ('Archway Publishing',), ('Syracuse University Press',), ('Sterling Publishing Company, Inc.',), ('Westminster John Knox Press',), ('Da Capo Press',), ('Amer Literary Press',), ('Corwin',), ('AuthorHouse',), ('Random House Books for Young Readers',), ('Red Room Press',), ('Faber & Faber',), ('Brandylane Publishers Inc',), ('Betty Crocker',), ('St Augustine PressInc',), ('McGraw-Hill/Irwin',), ('Vintage',), ('Overamstel Uitgevers',), ('Texas A&M University Press',), ('University of Arizona Press',), ('WestBow Press',), ('University of Georgia Press',), ('Lyons Press',), ('iUniverse',), ('Neil a Kjos Music Company',), ('Dau Pub',), ('Scholastic Paperbacks',), ('Cambridge Scholars Publishing',), ('London : G. Philip',), ('Health Science Publications',), ('Indiana University Press',), ('Silhouette',), ('Hal Leonard',), ('SAGE Publications',), ('Multnomah',), ('Teaching and Learning Company',), ('Taunton',), ('Houghton Mifflin Harcourt',), ('True Patriots Press',), ('Atlantic Publishing Company',), ('William Morrow & Company',), ('Spellmount, Limited Publishers',), ('Pearson College Division',), ('Pearson Educación',), ('Hill and Wang',), ('Boekerij',), ('Inner Light - Global communications',), ('Springer',), ('McFarland & Company Incorporated Pub',), ('Appa the Association of Higher Education Facilitie',), ('Weidenfeld & Nicolson',), ('Grub Street Cookery',), ('Associated University Presses',), ('Macmillan',), ('Oxford University Press, USA',), ('Oxford University Press',), ('Image',), ('Random House',), ('Read Books Ltd',), ('NYU Press',), ('Amer Chemical Society',), ('Touchstone',), ('Backlist, LLC - a unit of Chicken Soup of the Soul',), ('Taylor Trade Publications',), ('Laurence King Publishing',), ('Doubleday Books',), ('Black Cat',), ('Kodansha International',), ('Arco',), ('Scholastic Inc.',), ('Walker & Company',), ('G K Hall & Company',), ('Grove Press',), ('Farrar, Straus and Giroux',), ('Heimburger House Publishing Company',), ('Bezige Bij b.v., Uitgeverij De',), ('Greenwood Publishing Group',), ('Pergamon Press',), ('Southwater Pub',), ('Cardoza',), ('Conran Octopus',), ('Transaction Publishers',), ('Lerner Publishing Group',), ('CRC Press',), ('Pearson Education India',), ('Big Earth Publishing',), ('Siddha Yoga Publications',), ("Saint Martin's Paperbacks",), ('HarperCollins',), ('Allyn & Bacon',), ('Walter Foster',), ('Crossway Bibles',), ('Univ of California Press',), ('B&H Publishing Group',), ('Business Contact',), ('Macmillan Reference USA',), ('Gale Cengage',), ('Virtualbookworm Publishing',), ('The Rosen Publishing Group, Inc',), ('Pioneer Drama Service, Inc.',), ('Rowman & Littlefield',), ('Academy Chicago Publishers, Limited',), ('Longman Publishing Group',), ('Xlibris Corporation',), ('ISBS',), ('Baker Academic',), ('Oxford University Press on Demand',), ('Millbrook Press',), ('Redlight Manga',), ('Ballantine Books',), ('Crossroad 8 Avenue',), ('Baker Publishing Group',), ('Univ. of Queensland Press',), ('Dover',), ('W. W. Norton & Company',), ('Pustak Mahal',), ('Birch Lane Press',), ('Collins Reference',), ('Crcs Publications',), ('Currency',), ('Praeger',), ('Chelsea Green Publishing',), ('ANWB Media - Boeken & Gidsen',), ('Spruce Books',), ('Glencoe/McGraw-Hill School Publishing Company',), ('Univ of South Carolina Press',), ('Aspen Publishers',), ('Kingston, Jamaica : Ian Randle Publishers',), ('John Benjamins Publishing',), ('BoD – Books on Demand',), ('Harlequin',), ('Pearson Education',), ('Penguin Group USA',), ('Marvel Enterprises',), ('Dorling Kindersley Ltd',), ('Walter de Gruyter',), ('Springer Science & Business Media',), ('Harcourt',), ('Dell Publishing Company',), ('Que Publishing',), ('Harlequin Books',), ('Psychology Press',), ('McGraw Hill Professional',), ('Wesleyan University Press',), ('New Century Books',), ('Research & Education Assn',), ('Head of Zeus',), ('Gramercy',), ('Quality Press',), ('Emmaus Road Publishing',), ('Rutgers University Press',), ('Bantam',), ('Guilford Publications',), ('Paulinas',), ('Northland Pub',), ('Emerald Group Publishing',), ('Wiley-Blackwell',), ('Penguin UK',), ('City Lights Books',), ('Sams Publishing',), ('Haynes Publishing',), ('MIRA',), ('Harvard University Press',), ('Hyperion',), ('Harlequin Treasury-Harlequin Temptation 90s',), ('University Press of Kentucky',), ('Marmer',), ('Addison Wesley Publishing Company',), ('Nashville : American Association for State and Loc',), ('Stewart, Tabori and Chang',), ('Reed Reference Publishing',), ('Delacorte Press',), ('New Leaf Publishing Group',), ('Teacher Created Resources',), ('Bethany House Pub',), ('Teachers College Press',), ('Lucis Pub',), ('Crossroad',), ('Bethany House Publishers',), ('Anchor',), ('Duke University Press',), ('Dutton Adult',), ('Hodder Paperbacks',), ('Clarendon Press',), ('Farcountry Press',), ('Sagwan Press',), ('Government Printing Office',), ('Course Technology',), ('Focus on the Family Pub',), ('Harry N. Abrams',), ('Del Rey Books',), ('McGraw-Hill Professional Pub',), ('Berrett-Koehler Publishers',), ('Grand Central Pub',), ('Palala Press',), ('Nicolas-Hays, Inc.',), ('Follettbound',), ('Wipf and Stock Publishers',), ('Franciscan Media',), ('De Borsillo',), ('Mithec',), ('Crescent',), ('Wien : Brüder Hollinek',), ('Catholic Book Publishing Company',), ('New Press/ORIM',), ('Candlewick Press (MA)',), ('Safari Press',), ('RH Childrens Books',), ('Dark Horse Comics',), ('Hearst Communications',), ('Eros Comics',), ('Origin, Incorporated',), ('Lulu.com',), ('Primento',), ('John a Noble Collection',), ('Booklocker.Com Incorporated',), ('Harry N Abrams Incorporated',), ('Athelia Henrietta Press',), ('Houghton Mifflin Harcourt P',), ('Boston : Little, Brown',), ('Bucknell University Press',), ('Viking',), ('Bantam Dell Publishing Group',), ('University-Press.org',), ('World Wisdom, Inc',), ('Addison-Wesley Professional',), ('Jones & Bartlett Publishers',), ('Apa Publications (UK) Limited',), ('Soho Press',), ('Tyndale House Publishers, Inc.',), ('Janes Information Group',), ('Anderson Publishing Company (OH)',), ('The Lawbook Exchange, Ltd.',), ('Elsevier',), ('Baker Books',), ('SciTech Publishing',), ('Radar, Sonar and Navigation',), ('University of Hawaii Press',), ('Marble City Publishing',), ('FT Press',), ('University of Chicago Press',), ('Zed Books',), ('Yale University Press',), ('John Hunt Publishing',), ('Tuttle Pub',), ('SCM Press',), ('Zenith Press',), ('Thomas Nelson Incorporated',), ('Georgetown University Press',), ('Whitaker House',), ('Self Realization Fellowship Pub',), ('St Martins Press',), ('Kodansha',), ('Kaplan',), ('Putnam Publishing Group',), ('Brookings Institution Press',), ('Antique Trader',), ('Crabtree Publishing Company',), ("St. Martin's Griffin",), ('Blackstone Publishing',), ('White Wolf Pub',), ('Adams Media Corporation',), ('Vertical Inc',), ('Editions Moulinsart',), ('Pfeifer-Hamilton Pub',), ('Bloomsbury Methuen Drama',), ('ePublishing Works!',), ('Peter Owen Publishers',), ('New Directions Publishing',), ('JG Kids',), ('Abela Publishing Ltd',), ('Createspace Independent Pub',), ('National Council of Teachers',), ('Burns & Oates',), ('Universal-Publishers',), ('Mary Book / Prelude Press',), ('Frank Amato Publications',), ('Manteau Jeugd',), ('Bison Books',), ('Apress',), ('Createspace Independent Publishing Platform',), ('Rayo',), ('Smart Luck Pub',), ('Luba Trilogy',), ('Ace Books',), ('Patient-Centered Guides',), ('Coriolis Group',), ('ACP Press',), ('Basic Books',), ('Bethlehem Books',), ('Down East Books',), ('Manteau thriller',), ('Alfred Publishing Company, Incorporated',), ('Arcadia Publishing',), ('Publish America',), ('Van Patten Publishing',), ('New York : Grosset & Dunlap',), ('Ecco',), ('Lippincott Williams & Wilkins',), ('Sterling Publishing Company Incorporated',), ('Pearson Prentice Hall',), ('MIT Press',), ('Word Among Us Press',), ('Pomegranate',), ('Motorbooks International',), ('Itmb Pub Limited',), ('Copyright Office, Library of Congress',), ('Viking Press',), ('Nyrb Kids',), ('Master Media Publishing Corporation',), ('University of Texas Press',), ('American Univ in Cairo Press',), ('Wessex Astrologer Limited',), ('SUNY Press',), ('Rosetta Books',), ('Editions Gallimard',), ('National Geographic Books',), ('London : Heinemann',), ('Otto Harrassowitz',), ('Pelican Publishing',), ('McGraw-Hill Humanities/Social Sciences/Languages',), ('Sybex',), ('Audio Amateur Publications',), ('Granta Books',), ('Perigee Trade',), ('Large Print Press',), ('Cumberland House Publishing',), ('Signet',), ('Ohio University Press',), ('McGraw-Hill Osborne Media',), ('Sheridan House, Inc.',), ('Dufour Editions',), ('ReadHowYouWant.com',), ('Common Reader Editions',), ('Modern Library',), ('New York Review of Books',), ('Wm. B. Eerdmans Publishing Company',), ('Morgan Kaufmann',), ('Academic Press',), ('Aeterna Press',), ('LA Leche League International',), ('Luc de Ruijter',), ('Genealogical Publishing Com',), ('Courier Dover Publications',), ('Harcourt Childrens Books',), ('Little, Brown',), ('Willie M. Giles',), ('Publishamerica Incorporated',), ('Pen & Sword',), ('Paul s Eriksson',), ('Russell Sage Foundation',), ('Flying Cloud Pub',), ('William B. Eerdmans Publishing Company',), ('Morning Glory Press (CA)',), ('Running Press Book Publishers',), ('Kodansha Comics',), ('DK Children',), ('Sybex Incorporated',), ('Harpercollins',), ('Stackpole Books',), ('Pan Macmillan',), ('Uitgeverij Kok',), ('Berkley Trade',), ('Harvard Common Press',), ("Brassey's Incorporated",), ('TokyoPop',), ('University of Pennsylvania Press',), ('Ebooksonthe.Net',), ('Redmond, Wash. : Microsoft Press',), ('Destiny Image Publishers',), ('Lannoo Uitgeverij',), ('Edward Elgar Publishing',), ('Plural Publishing',), ('American Psychiatric Pub',), ('Atrium Verlag AG Zürich',), ('IOS Press',), ('Fox Chapel Publishing Company Incorporated',), ('Creative Publishing International',), ('Tempus Pub Limited',), ('Dog Ear Publishing',), ('New Issues Poetry & Prose',), ('Rising Moon Books for Young Readers',), ('Bantam Books',), ('Haskell House Pub Limited',), ('Longtail Publishing',), ('Cengage Learning',), ('Isa',), ('CreateSpace',), ('Scarecrow Press',), ('New York : Knopf',), ('Amsco Music',), ('Christopher-Gordon Pub',), ('Potomac Books Incorporated',), ('Mills & Boon',), ('McGraw-Hill',), ('Atlas Contact',), ('Barabara Press',), ('Springer Nature',), ('Twenty-Third Publications',), ('Copper Beach Books',), ('Pyr',), ('Lothrop Lee & Shepard',), ('Enslow Pub Incorporated',), ('Publish Indy',), ('University of Nevada Press',), ('Wilderness Press',), ('Gareth Stevens Pub',), ('Black Belt Communications',), ('Ruth Inst Books',), ('Lemniscaat Publishers',), ('University Press of America',), ('Starrhill Press',), ('Alfred Music',), ('Fair Winds Press',), ('Cato Institute',), ('august house',), ('Penguin Books',), ('Thunder Bay Press',), ('University of Ottawa Press',), ('McGraw-Hill Professional Publishing',), ('Del Rey',), ('Orenda Books',), ('Miramax',), ('Workman Publishing',), ('Aadarsh',), ('Chinese University Press',), ('Pearson',), ('Oregon Historical Society Press',), ('Inter-Varsity Press',), ('Random House Incorporated',), ('Contemporary Books',), ('Puffin Books',), ('Prabhat Prakashan',), ('Merrell Pub Limited',), ('Sourcebooks, Inc.',), ('BelleBooks',), ('Redemption Press',), ('Wm. B. Eerdmans Publishing',), ('Presbyterian Publishing Corp',), ('Voyager Books',), ('Strelbytskyy Multimedia Publishing',), ('GENERAL PRESS',), ('W W Norton & Company Incorporated',), ('Junior League of North Harries',), ('Vintage Canada',), ('Arte Publico Press',), ('*Howell Book House',), ('Thomas Nelson Inc',), ('Crandall Dostie & Douglass Books',), ('Timber Press',), ('Crystal Clarity Pubs',), ('T.A. Daly Studio',), ('White Dei',), ('Circlet Press',), ('Smyth & Helwys Publishing, Inc.',), ('Univ of North Carolina Press',), ('Ave Maria Press',), ('Christian Liberty Press',), ('Random House Value Pub',), ('Harvard Business Press',), ('Thomas & Mercer',), ('HarperOne',), ('Holiday House',), ('Simon & Schuster',), ('Fantagraphics Books',), ('One World',), ('HMH',), ('Catholic Basics: A Pastoral Mi',), ("St. Martin's Press",), ('Shuttle Craft Books',), ('Lorenz Books',), ('Quinlan Press (MA)',), ('Minotaur Books',), ('Newmarket Press',), ('Carroll & Graf Pub',), ('Marian Press',), ('Graymalkin Media',), ('Wilder Publications Limited',), ('World Scientific',), ('SAGE',), ('Scalo Verlag Ac',), ('Amberley Publishing Limited',), ("Company's Coming Publishing",), ('Manchester University Press',), ('Amber-Allen Publishing',), ('Bridge Logos Inc',), ('Little Apple',), ('Henry Holt and Company',), ('Capstone',), ('David De Angelis',), ("Author's Choice Publishing",), ('Sutton Pub Limited',), ('Creative Commons',), ('Augsburg Fortress Pub',), ('Hazelden Publishing',), ('Orion',), ('Broadway',), ('Dan Millman',), ('LSU Press',), ('Signet Book',), ('Clarion Books',), ('VNR AG',), ('Schocken',), ('Andrews McMeel Pub',), ('Thomas Dunne Books',), ('Atlantic Books',), ('Univ of Massachusetts Press',), ('Merriam Webster Mass Market',), ('Crossway',), ('Albert Whitman',), ('Greenwood',), ('Palgrave Macmillan',), ('Howell Book House',), ('Dell',), ('Crippen & Landru Publishers',), ('Dorrance Publishing',), ('AFRICAN SUN MeDIA',), ('Have, Ten',), ('London : Barker',), ('Funstory',), ('Human Kinetics',), ('Spectra',), ('Harmony',), ('R. R. Bowker',), ('Amer Eagle Publications Incorporated',), ('Silvana Editoriale',), ('Transaction Large Print',), ("McGill-Queen's Press - MQUP",), ('De Fontein Romans & Spanning',), ('Smith & Kraus Pub Incorporated',), ('Allison & Busby',), ('Harrison House Publishers',), ('Elt Press',), ('Red Wheel',), ('Springer Publishing Company',), ('TSR',), ('Spectrum',), ('Gallery Books',), ('Kirkbride Bible Company',), ('Publishing Solutions, LLC',), ('Bloomsbury Publishing',), ('Lincoln, Nebraska',), ('Prometheus Books',), ('AnkhHermes, Uitgeverij',), ('Heinemann',), ('Corwin Press',), ('Upper Room',), ('Cosimo, Inc.',), ('Infinity Publishing',), ('Specialist Interest Model Books Limited',), ('Mark V Ziesing',), ('New York : Harper',), ('Cornell University Press',), ('Blue Door',), ('Editions Assouline',), ('Bloomsbury Publishing USA',), ('Lulu Press, Inc',), ('Emily Martinsen',), ('Orb Books',), ('Sure Sellers Incorporated',), ("St. Martin's Essentials",), ('Musaicum Books',), ('Garden City, N.Y : Doubleday',), ('Karakter',), ('Woodland Pub',), ('Ambo|Anthos',), ('Boydell & Brewer',), ('Westview Press',), ('Xulon Press',), ('Schiffer Book for Collectors',), ('Wordsworth Editions',), ('IndyPublish.com',), ('University of Oklahoma Press',), ('Pearson Learning Solutions',), ('FriesenPress',), ('Race Point Pub',), ('Crown',), ('Moody Publishers',), ('Tata McGraw-Hill Education',), ('F+W Media, Inc.',), ('Stoddart',), ('Irwin Professional Pub',), ('Little, Brown Books for Young Readers',), ('Alpha Test',), ('William H Sadlier',), ('Baen Books',), ('Amsterdam University Press',), ('Englewood, Colo. : Libraries Unlimited',), ('Pinnacle Books',), ('Giffodess Books',), ('Society for Industrial & Applied',), ('Cooper Square Pub',), ('Alfred Music Publishing',), ('StarWalk Kids Media',), ('Tfh Publications Incorporated',), ('Greenwillow',), ('Thomas Nelson',), ('Boynton/Cook',), ('Bethany House',), ("G.P. Putnam's Sons",), ('Ishi Press',), ('Beacon Hill Press',), ('DoctorZed Publishing',), ('Macmillan Pub Limited',), ('Pocket Books',), ('Crown Pub',), ('William Morrow Paperbacks',), ('PediaPress',), ('Zondervan Academic',), ('Pan Books',), ('Club Readership',), ('Amber House Books',))

s = Counter([c[0] for c in a])
s.most_common(1)
# Out:
# [('', 1)]

# %%
import pandas as pd
import random as rand
import os


# current_path = os.path.dirname(__file__)
# parent_folder = os.path.abspath(os.path.join(current_path, os.pardir))
# data_folder = os.path.join(os.pardir, "../data/")


books = pd.read_csv("../../data/books_data.csv")
books = books.fillna(0)




# for i in ["isbn13", "original_title","original_publication_year"]:
#     book_info[i] = books[i]


def bookdata(df=books):
    book_tuples = []
    for i in range(len(books)):
        isbn13 = int(books.iloc[i]["isbn13"])
        original_title = books.iloc[i]["original_title"]
        original_publication_year = int(books.iloc[i]["original_publication_year"])
        publisher = "filler"
        desc = "filler"
        book_tuples.append((isbn13, original_title, original_publication_year, publisher, desc))
    return tuple(book_tuples)

# books[books"original_publication_year"] > ]

# %%
import pathlib

# parent_project_path = pathlib.Path(os.path.dirname(__file__)).parents[1]
# data_folder = parent_project_path/"data"
# print(parent_project_path)
# alt books data
books_data = pd.read_csv("../../data/books_data.csv", index_col="Title")
books = pd.read_csv("../../data/books.csv")


books_data
# books.set_index("title")
# books_data.set_index("Title")
# Out:
#                                                                                           description  \
# Title
# Its Only Art If Its Well Hung!                                                                    NaN
# Dr. Seuss: American Icon                            Philip Nel takes a fascinating look into the k...
# Wonderful Worship in Smaller Churches               This resource includes twelve principles in un...
# Whispers of the Wicked Saints                       Julia Thomas finds her life spinning out of co...
# Nation Dance: Religion, Identity and Cultural D...                                                NaN
# ...                                                                                               ...
# The Orphan Of Ellis Island (Time Travel Adventu...  During a school trip to Ellis Island, Dominick...
# Red Boots for Christmas                             Everyone in the village of Friedensdorf is hap...
# ...

# %%
n_books_per_shelf = 210

n_bookshelves = books_data.size / n_books_per_shelf

def auto_truncate(val, length:int):
    return val[:length]

# parent_project_path = pathlib.Path(os.path.dirname(__file__)).parents[1]
# data_folder = parent_project_path/"data"
books_data = pd.read_csv(
    "../../data/books_data.csv",
    converters={
        "publisher":lambda x: auto_truncate(x, 50),
        "Title":lambda x: auto_truncate(x, 255),
        "categories": lambda x: x[2:-2],
        },
    nrows=100_000
    )
books_data = books_data.drop_duplicates(subset = "Title")
books_data["publishedDate"] = books_data["publishedDate"].fillna("-9999")
books_data["publishedDate"] = books_data["publishedDate"].str.replace(r'\?', '0', regex=True)
books_data["publishedDate"] = books_data["publishedDate"].str.extract(r"(^-?\d{,4})")
books_data["publishedDate"] = books_data["publishedDate"].astype('int')
books_data["publisher"] = pd.Categorical(books_data["publisher"])
books_data["categories"] = pd.Categorical(books_data["categories"])
books_data = books_data.where(pd.notnull(books_data), None)
books_data["ratingsCount"] = books_data["ratingsCount"].fillna(0)
books_data.sort_values(by='Title',inplace=True)

# books_data.iloc[44417]
# books_data = books_data.dropna(axis=0)
books2 = books_data.copy()
books2.sort_values(by='Title',inplace=True)
books2
# books2[books2['authors'] == "['Maharshi Ramana']"]
# Out:
#                                                    Title  \
# 1066
# 28608  " We'll Always Have Paris": The Definitive Gui...
# 45101                                     "Ace" Any Test
# 61725                        "Ah so!": Japanese for kids
# 44417     "Anna, where are you?" (A Miss Silver mystery)
# ...                                                  ...
# 84671                              why only words: poems
# 14373                                   wide is the gate
# 91449                           with an everlasting love
# 64773                                work and Motivation
# 84075                             www.whitbread.org/book
#
#                                              description  \
# 1066                                                None
# 28608  This ultimate compilation of more than 11,000 ...
# 45101  A practical guide for effective test prep with...
# 61725  This fun introduction to Japanese teaches hund...
# ...

# %%
class Bookshelf:
    def __init__(self,ind:int=0,category:str = 'Misc'):
        self.category = category
        self.bookshelfID = ind
        self.full = False
        self.subshelves = {
            '01': [],
            '02': [],
            '03': [],
            '04': [],
            '05': [],
            '06': [],
            '07': [],
        }
    def append(self, bookID):
        for shelf_number, books in self.subshelves.items():
            if len(books) < 30:
                books.append(bookID)
                break
        else:
            self.full = True
            return "Full"
    def read(self):
        print(f"Bookshelf: {self.bookshelfID}\nCategory: {self.category}")
        for shelf in self.subshelves.values():
            print(shelf)
    def index(self):
        finallist = []
        b_id = f"{self.bookshelfID:03d}"
        for subshelf,books in self.subshelves.items():
            for book_id in books:
                finallist.append(f"{b_id}-{subshelf}-{book_id}")
        return finallist

def populate_bookshelves(ids,startint=1,category:str='Misc'):
    """Builds bookshelf data
    Args: iterable of bookIDs


    Returns: List of bookshelf objects




    """
    bookshelves = [Bookshelf(startint,category)]
    next_bookshelf_id = startint + 1
    for i in ids:
        book_added = False
        for bookshelf in bookshelves:
            result = bookshelf.append(i)
            if result is None:
                book_added = True
                break

        if not book_added:
            # If all bookshelves are full, create a new bookshelf
            new_bookshelf = Bookshelf(next_bookshelf_id)
            new_bookshelf.category = category
            bookshelves.append(new_bookshelf)
            new_bookshelf.append(i)  # Add the book to the new bookshelf
            # print(f"Created Bookshelf{len(bookshelves)} for book {i}")
            next_bookshelf_id += 1

    return bookshelves

# populate_bookshelves(range(1000))[0].read()

# %%
def generate_shelf_decimal(books_data):
    books2 = books_data.copy()
    books2.replace("","Misc",inplace=True)
    grouped = books2.groupby(by='categories')
    library = []
    misc_cats = []

    startint = True
    for cat,group in grouped:
        if len(group) <= 200:
            misc_cats.append(cat)
        else:

            if startint:
                library.extend(populate_bookshelves(group.index,category=cat))
                startint = False
            else:
                library.extend(populate_bookshelves(group.index,startint=len(library)+1,category=cat))

    last_int = library[-1].bookshelfID

    misc = books2[books2['categories'].isin(misc_cats)]
    library.extend(populate_bookshelves(misc.index,startint=last_int,category="Misc",))


    indices = []
    for bookshelf in library:
        indices.extend(bookshelf.index())
    print(f"Generating {len(library)} bookshelves containing {len(indices)} books")

    # for bookshelf in library:
    #     print(f"Bookshelf ID: {bookshelf.bookshelfID}")
    return indices
generate_shelf_decimal(books_data)
# Out:
# C:\Users\Jayden\AppData\Local\Temp\ipykernel_14532\1859905610.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = books2.groupby(by='categories')
# Generating 503 bookshelves containing 100000 books
# ['001-01-1066',
#  '001-01-44417',
#  '001-01-91080',
#  '001-01-43412',
#  '001-01-74361',
#  '001-01-156',
#  '001-01-38629',
#  '001-01-38130',
#  '001-01-72726',
#  '001-01-58971',
#  '001-01-73163',
#  '001-01-1315',
#  '001-01-66776',
#  '001-01-71550',
#  '001-01-86759',
#  '001-01-94882',
#  '001-01-89213',
#  '001-01-70009',
#  '001-01-72618',
#  '001-01-72535',
#  '001-01-83419',
#  '001-01-91889',
#  '001-01-47570',
#  '001-01-65835',
#  '001-01-58806',
#  '001-01-77069',
#  '001-01-10978',
#  '001-01-4602',
#  '001-01-73102',
#  '001-01-82803',
#  '001-02-80315',
# ...
