# %%
import pandas as pd
import random as rand
import os


# current_path = os.path.dirname(__file__)
# parent_folder = os.path.abspath(os.path.join(current_path, os.pardir))
# data_folder = os.path.join(os.pardir, "../data/")


books = pd.read_csv("../../data/books_data.csv")
books = books.fillna(0)




# for i in ["isbn13", "original_title","original_publication_year"]:
#     book_info[i] = books[i]


def bookdata(df=books):
    book_tuples = []
    for i in range(len(books)):
        isbn13 = int(books.iloc[i]["isbn13"])
        original_title = books.iloc[i]["original_title"]
        original_publication_year = int(books.iloc[i]["original_publication_year"])
        publisher = "filler"
        desc = "filler"
        book_tuples.append((isbn13, original_title, original_publication_year, publisher, desc))
    return tuple(book_tuples)

# books[books"original_publication_year"] > ]

# %%
import pathlib

# parent_project_path = pathlib.Path(os.path.dirname(__file__)).parents[1]
# data_folder = parent_project_path/"data"
# print(parent_project_path)
# alt books data
books_data = pd.read_csv("../../data/books_data.csv", index_col="Title")
books = pd.read_csv("../../data/books.csv")


books_data
# books.set_index("title")
# books_data.set_index("Title")
# Out:
#                                                                                           description  \
# Title
# Its Only Art If Its Well Hung!                                                                    NaN
# Dr. Seuss: American Icon                            Philip Nel takes a fascinating look into the k...
# Wonderful Worship in Smaller Churches               This resource includes twelve principles in un...
# Whispers of the Wicked Saints                       Julia Thomas finds her life spinning out of co...
# Nation Dance: Religion, Identity and Cultural D...                                                NaN
# ...                                                                                               ...
# The Orphan Of Ellis Island (Time Travel Adventu...  During a school trip to Ellis Island, Dominick...
# Red Boots for Christmas                             Everyone in the village of Friedensdorf is hap...
# Mamaw                                               Give your Mamaw a useful, beautiful and though...
# The Autograph Man                                   Alex-Li Tandem sells autographs. His business ...
# Student's Solutions Manual for Johnson/Mowry's ...  Discover the many ways mathematics is relevant...
#
#                                                                                     authors  \
# Title
# Its Only Art If Its Well Hung!                                             ['Julie Strain']
# Dr. Seuss: American Icon                                                     ['Philip Nel']
# Wonderful Worship in Smaller Churches                                      ['David R. Ray']
# Whispers of the Wicked Saints                                           ['Veronica Haddon']
# Nation Dance: Religion, Identity and Cultural D...                          ['Edward Long']
# ...                                                                                     ...
# The Orphan Of Ellis Island (Time Travel Adventu...                      ['Elvira Woodruff']
# Red Boots for Christmas                                                                 NaN
# Mamaw                                                                 ['Wild Wild Cabbage']
# The Autograph Man                                                           ['Zadie Smith']
# Student's Solutions Manual for Johnson/Mowry's ...  ['David B. Johnson', 'Thomas A. Mowry']
#
#                                                                                                 image  \
# Title
# Its Only Art If Its Well Hung!                      http://books.google.com/books/content?id=DykPA...
# Dr. Seuss: American Icon                            http://books.google.com/books/content?id=IjvHQ...
# Wonderful Worship in Smaller Churches               http://books.google.com/books/content?id=2tsDA...
# Whispers of the Wicked Saints                       http://books.google.com/books/content?id=aRSIg...
# Nation Dance: Religion, Identity and Cultural D...                                                NaN
# ...                                                                                               ...
# The Orphan Of Ellis Island (Time Travel Adventu...  http://books.google.com/books/content?id=J7M-N...
# Red Boots for Christmas                             http://books.google.com/books/content?id=3n8k6...
# Mamaw                                                                                             NaN
# The Autograph Man                                   http://books.google.com/books/content?id=JM6YV...
# Student's Solutions Manual for Johnson/Mowry's ...  http://books.google.com/books/content?id=dehfP...
#
#                                                                                           previewLink  \
# Title
# Its Only Art If Its Well Hung!                      http://books.google.nl/books?id=DykPAAAACAAJ&d...
# Dr. Seuss: American Icon                            http://books.google.nl/books?id=IjvHQsCn_pgC&p...
# Wonderful Worship in Smaller Churches               http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# Whispers of the Wicked Saints                       http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# Nation Dance: Religion, Identity and Cultural D...  http://books.google.nl/books?id=399SPgAACAAJ&d...
# ...                                                                                               ...
# The Orphan Of Ellis Island (Time Travel Adventu...  http://books.google.com/books?id=J7M-NwAACAAJ&...
# Red Boots for Christmas                             http://books.google.com/books?id=3n8k6wl4BbYC&...
# Mamaw                                               http://books.google.com/books?id=zytVswEACAAJ&...
# The Autograph Man                                   http://books.google.com/books?id=JM6YVPx_clMC&...
# Student's Solutions Manual for Johnson/Mowry's ...  http://books.google.com/books?id=dehfPgAACAAJ&...
#
#                                                                          publisher  \
# Title
# Its Only Art If Its Well Hung!                                                 NaN
# Dr. Seuss: American Icon                                                 A&C Black
# Wonderful Worship in Smaller Churches                                          NaN
# Whispers of the Wicked Saints                                            iUniverse
# Nation Dance: Religion, Identity and Cultural D...                             NaN
# ...                                                                            ...
# The Orphan Of Ellis Island (Time Travel Adventu...           Scholastic Paperbacks
# Red Boots for Christmas                                                        NaN
# Mamaw                                                                          NaN
# The Autograph Man                                                          Vintage
# Student's Solutions Manual for Johnson/Mowry's ...  Brooks/Cole Publishing Company
#
#                                                    publishedDate  \
# Title
# Its Only Art If Its Well Hung!                              1996
# Dr. Seuss: American Icon                              2005-01-01
# Wonderful Worship in Smaller Churches                       2000
# Whispers of the Wicked Saints                            2005-02
# Nation Dance: Religion, Identity and Cultural D...    2003-03-01
# ...                                                          ...
# The Orphan Of Ellis Island (Time Travel Adventu...    2000-06-01
# Red Boots for Christmas                                     1995
# Mamaw                                                 2018-01-17
# The Autograph Man                                     2003-08-12
# Student's Solutions Manual for Johnson/Mowry's ...    1998-01-01
#
#                                                                                              infoLink  \
# Title
# Its Only Art If Its Well Hung!                      http://books.google.nl/books?id=DykPAAAACAAJ&d...
# Dr. Seuss: American Icon                            http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# Wonderful Worship in Smaller Churches               http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# Whispers of the Wicked Saints                       http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# Nation Dance: Religion, Identity and Cultural D...  http://books.google.nl/books?id=399SPgAACAAJ&d...
# ...                                                                                               ...
# The Orphan Of Ellis Island (Time Travel Adventu...  http://books.google.com/books?id=J7M-NwAACAAJ&...
# Red Boots for Christmas                             http://books.google.com/books?id=3n8k6wl4BbYC&...
# Mamaw                                               http://books.google.com/books?id=zytVswEACAAJ&...
# The Autograph Man                                   https://play.google.com/store/books/details?id...
# Student's Solutions Manual for Johnson/Mowry's ...  http://books.google.com/books?id=dehfPgAACAAJ&...
#
#                                                                        categories  \
# Title
# Its Only Art If Its Well Hung!                        ['Comics & Graphic Novels']
# Dr. Seuss: American Icon                            ['Biography & Autobiography']
# Wonderful Worship in Smaller Churches                                ['Religion']
# Whispers of the Wicked Saints                                         ['Fiction']
# Nation Dance: Religion, Identity and Cultural D...                            NaN
# ...                                                                           ...
# The Orphan Of Ellis Island (Time Travel Adventu...           ['Juvenile Fiction']
# Red Boots for Christmas                                      ['Juvenile Fiction']
# Mamaw                                                                         NaN
# The Autograph Man                                                     ['Fiction']
# Student's Solutions Manual for Johnson/Mowry's ...                            NaN
#
#                                                     ratingsCount
# Title
# Its Only Art If Its Well Hung!                               NaN
# Dr. Seuss: American Icon                                     NaN
# Wonderful Worship in Smaller Churches                        NaN
# Whispers of the Wicked Saints                                NaN
# Nation Dance: Religion, Identity and Cultural D...           NaN
# ...                                                          ...
# The Orphan Of Ellis Island (Time Travel Adventu...           2.0
# Red Boots for Christmas                                      NaN
# Mamaw                                                        NaN
# The Autograph Man                                           19.0
# Student's Solutions Manual for Johnson/Mowry's ...           NaN
#
# [212404 rows x 9 columns]

# %%
n_books_per_shelf = 210

n_bookshelves = books_data.size / n_books_per_shelf

def auto_truncate(val, length:int):
    return val[:length]

# parent_project_path = pathlib.Path(os.path.dirname(__file__)).parents[1]
# data_folder = parent_project_path/"data"
books_data = pd.read_csv(
    "../../data/books_data.csv",
    converters={
        "publisher":lambda x: auto_truncate(x, 50),
        "Title":lambda x: auto_truncate(x, 255),
        "categories": lambda x: x[2:-2],
        },
    nrows=100_000
    )
books_data = books_data.drop_duplicates(subset = "Title")
books_data["publishedDate"] = books_data["publishedDate"].fillna("-9999")
books_data["publishedDate"] = books_data["publishedDate"].str.replace(r'\?', '0', regex=True)
books_data["publishedDate"] = books_data["publishedDate"].str.extract(r"(^-?\d{,4})")
books_data["publishedDate"] = books_data["publishedDate"].astype('int')
books_data["publisher"] = pd.Categorical(books_data["publisher"])
books_data["categories"] = pd.Categorical(books_data["categories"])
books_data = books_data.where(pd.notnull(books_data), None)
books_data["ratingsCount"] = books_data["ratingsCount"].fillna(0)
books_data.sort_values(by='Title',inplace=True)

# books_data.iloc[44417]
# books_data = books_data.dropna(axis=0)
books2 = books_data.copy()
books2.sort_values(by='Title',inplace=True)
books2
# books2[books2['authors'] == "['Maharshi Ramana']"]
# Out:
#                                                    Title  \
# 1066
# 28608  " We'll Always Have Paris": The Definitive Gui...
# 45101                                     "Ace" Any Test
# 61725                        "Ah so!": Japanese for kids
# 44417     "Anna, where are you?" (A Miss Silver mystery)
# ...                                                  ...
# 84671                              why only words: poems
# 14373                                   wide is the gate
# 91449                           with an everlasting love
# 64773                                work and Motivation
# 84075                             www.whitbread.org/book
#
#                                              description  \
# 1066                                                None
# 28608  This ultimate compilation of more than 11,000 ...
# 45101  A practical guide for effective test prep with...
# 61725  This fun introduction to Japanese teaches hund...
# 44417                                               None
# ...                                                  ...
# 84671  Harper was a freed African American woman from...
# 14373  Upton Sinclair’s Pulitzer Prize–winning saga c...
# 91449  This allegorical novel explores the love of Go...
# 64773  This book provides a unique behavioral science...
# 84075                                               None
#
#                                                authors  \
# 1066                               ['Maharshi Ramana']
# 28608  ['Robert A. Nowlan', 'Gwendolyn Wright Nowlan']
# 45101                                      ['Ron Fry']
# 61725                                 ['Carole Marsh']
# 44417                                             None
# ...                                                ...
# 84671                 ['Frances Ellen Watkins Harper']
# 14373                               ['Upton Sinclair']
# 91449                                   ['Kay Arthur']
# 64773                               ['Gary P. Latham']
# 84075                                             None
#
#                                                    image  \
# 1066   http://books.google.com/books/content?id=uq0uj...
# 28608  http://books.google.com/books/content?id=H1YqN...
# 45101  http://books.google.com/books/content?id=JHBjD...
# 61725  http://books.google.com/books/content?id=56F8A...
# 44417                                               None
# ...                                                  ...
# 84671  http://books.google.com/books/content?id=z0vmx...
# 14373  http://books.google.com/books/content?id=puMlC...
# 91449  http://books.google.com/books/content?id=2A8fF...
# 64773  http://books.google.com/books/content?id=LmApk...
# 84075                                               None
#
#                                              previewLink  \
# 1066   http://books.google.nl/books?id=uq0ujwEACAAJ&d...
# 28608  http://books.google.com/books?id=H1YqNQAACAAJ&...
# 45101  http://books.google.com/books?id=JHBjDwAAQBAJ&...
# 61725  http://books.google.com/books?id=56F8Af2cYMIC&...
# 44417                                               None
# ...                                                  ...
# 84671  http://books.google.com/books?id=z0vmxcwxlrEC&...
# 14373  http://books.google.nl/books?id=puMlCwAAQBAJ&p...
# 91449  http://books.google.com/books?id=2A8fFSfhdSEC&...
# 64773  http://books.google.com/books?id=LmApklWApCQC&...
# 84075                                               None
#
#                       publisher  publishedDate  \
# 1066                                      2015
# 28608                 Perennial           1994
# 45101           Open Road Media           2018
# 61725   Gallopade International           2004
# 44417                                    -9999
# ...                         ...            ...
# 84671                                     1855
# 14373           Open Road Media           2016
# 91449  Harvest House Publishers           1999
# 64773                      SAGE           2012
# 84075                                    -9999
#
#                                                 infoLink  \
# 1066   http://books.google.nl/books?id=uq0ujwEACAAJ&d...
# 28608  http://books.google.com/books?id=H1YqNQAACAAJ&...
# 45101  https://play.google.com/store/books/details?id...
# 61725  https://play.google.com/store/books/details?id...
# 44417                                               None
# ...                                                  ...
# 84671  https://play.google.com/store/books/details?id...
# 14373  https://play.google.com/store/books/details?id...
# 91449  http://books.google.com/books?id=2A8fFSfhdSEC&...
# 64773  http://books.google.com/books?id=LmApklWApCQC&...
# 84075                                               None
#
#                  categories  ratingsCount
# 1066                                  1.0
# 28608             Reference           0.0
# 45101            Study Aids           0.0
# 61725   Juvenile Nonfiction           2.0
# 44417                                 0.0
# ...                     ...           ...
# 84671                                 0.0
# 14373               Fiction           0.0
# 91449              Religion           4.0
# 64773  Business & Economics           0.0
# 84075                                 0.0
#
# [100000 rows x 10 columns]

# %%
import random
class Bookshelf:
    def __init__(self,ind:int=0,category:str = 'Misc'):
        self.category = category
        self.bookshelfID = ind
        self.full = False
        self.subshelves = {
            '01': [],
            '02': [],
            '03': [],
            '04': [],
            '05': [],
            '06': [],
            '07': [],
        }
    def append(self, bookID):
        for shelf_number, books in self.subshelves.items():
            if len(books) < 30:
                books.append(bookID)
                break
        else:
            self.full = True
            return "Full"
    def read(self):
        print(f"Bookshelf: {self.bookshelfID}\nCategory: {self.category}")
        for shelf in self.subshelves.values():
            print(shelf)
    def index(self):
        finallist = []
        b_id = f"{self.bookshelfID:03d}"
        for subshelf,books in self.subshelves.items():
            for book_id in books:
                finallist.append((f"{b_id}-{subshelf}-{book_id}",book_id,random.randint(0,2)))
        return finallist

def populate_bookshelves(ids,startint=1,category:str='Misc'):
    """Builds bookshelf data
    Args: iterable of bookIDs


    Returns: List of bookshelf objects
    
    
    
    
    """
    bookshelves = [Bookshelf(startint,category)]
    next_bookshelf_id = startint + 1
    for i in ids:
        book_added = False
        for bookshelf in bookshelves:
            result = bookshelf.append(i)
            if result is None: 
                book_added = True
                break

        if not book_added:
            # If all bookshelves are full, create a new bookshelf
            new_bookshelf = Bookshelf(next_bookshelf_id)
            new_bookshelf.category = category
            bookshelves.append(new_bookshelf)
            new_bookshelf.append(i)  # Add the book to the new bookshelf
            # print(f"Created Bookshelf{len(bookshelves)} for book {i}")
            next_bookshelf_id += 1

    return bookshelves

# populate_bookshelves(range(1000))[0].read()

# %%
import random
def generate_shelf_decimal(books_data):
    books2 = books_data.copy()
    books2.replace("","Misc",inplace=True)
    grouped = books2.groupby(by='categories')
    library = []
    misc_cats = []

    startint = True
    for cat,group in grouped:
        if len(group) <= 200:
            misc_cats.append(cat)
        else:

            if startint:
                library.extend(populate_bookshelves(group.index,category=cat))
                startint = False
            else:
                library.extend(populate_bookshelves(group.index,startint=len(library)+1,category=cat))

    last_int = library[-1].bookshelfID

    misc = books2[books2['categories'].isin(misc_cats)]
    library.extend(populate_bookshelves(misc.index,startint=last_int,category="Misc",))


    indices = []
    for bookshelf in library:
        indices.extend(bookshelf.index())
    print(f"Generating {len(library)} bookshelves containing {len(indices)} books")

    # for bookshelf in library:
    #     print(f"Bookshelf ID: {bookshelf.bookshelfID}")  
    return tuple(indices)
generate_shelf_decimal(books_data)
# Out:
# C:\Users\Jayden\AppData\Local\Temp\ipykernel_14532\3361253582.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = books2.groupby(by='categories')
# Generating 503 bookshelves containing 100000 books
# (('001-01-1066', 1066, 2),
#  ('001-01-44417', 44417, 0),
#  ('001-01-91080', 91080, 1),
#  ('001-01-43412', 43412, 1),
#  ('001-01-74361', 74361, 2),
#  ('001-01-156', 156, 0),
#  ('001-01-38629', 38629, 1),
#  ('001-01-38130', 38130, 1),
#  ('001-01-72726', 72726, 2),
#  ('001-01-58971', 58971, 2),
#  ('001-01-73163', 73163, 0),
#  ('001-01-1315', 1315, 1),
#  ('001-01-66776', 66776, 0),
#  ('001-01-71550', 71550, 2),
#  ('001-01-86759', 86759, 1),
#  ('001-01-94882', 94882, 0),
#  ('001-01-89213', 89213, 1),
#  ('001-01-70009', 70009, 1),
#  ('001-01-72618', 72618, 2),
#  ('001-01-72535', 72535, 2),
#  ('001-01-83419', 83419, 1),
#  ('001-01-91889', 91889, 1),
#  ('001-01-47570', 47570, 1),
#  ('001-01-65835', 65835, 2),
#  ('001-01-58806', 58806, 2),
#  ('001-01-77069', 77069, 2),
#  ('001-01-10978', 10978, 0),
#  ('001-01-4602', 4602, 0),
#  ('001-01-73102', 73102, 1),
#  ('001-01-82803', 82803, 1),
#  ('001-02-80315', 80315, 2),
#  ('001-02-94618', 94618, 0),
#  ('001-02-86293', 86293, 0),
#  ('001-02-87864', 87864, 1),
#  ('001-02-834', 834, 2),
#  ('001-02-70119', 70119, 2),
#  ('001-02-39836', 39836, 1),
#  ('001-02-4317', 4317, 2),
#  ('001-02-64078', 64078, 1),
#  ('001-02-22009', 22009, 1),
#  ('001-02-86182', 86182, 2),
#  ('001-02-82720', 82720, 2),
#  ('001-02-85169', 85169, 2),
#  ('001-02-65953', 65953, 1),
#  ('001-02-7982', 7982, 2),
#  ('001-02-19604', 19604, 1),
#  ('001-02-28798', 28798, 0),
#  ('001-02-82701', 82701, 1),
#  ('001-02-14982', 14982, 1),
#  ('001-02-94720', 94720, 0),
#  ('001-02-19374', 19374, 2),
#  ('001-02-87880', 87880, 2),
#  ('001-02-57953', 57953, 1),
#  ('001-02-79218', 79218, 1),
#  ('001-02-63818', 63818, 1),
#  ('001-02-35601', 35601, 0),
#  ('001-02-35258', 35258, 2),
#  ('001-02-8763', 8763, 0),
#  ('001-02-327', 327, 2),
#  ('001-02-39499', 39499, 2),
#  ('001-03-65966', 65966, 1),
#  ('001-03-71328', 71328, 1),
#  ('001-03-6202', 6202, 0),
#  ('001-03-55718', 55718, 0),
#  ('001-03-95087', 95087, 1),
#  ('001-03-67847', 67847, 1),
#  ('001-03-80236', 80236, 2),
#  ('001-03-76530', 76530, 1),
#  ('001-03-78752', 78752, 1),
#  ('001-03-20818', 20818, 1),
#  ('001-03-87415', 87415, 2),
#  ('001-03-73422', 73422, 0),
#  ('001-03-38314', 38314, 1),
#  ('001-03-60182', 60182, 0),
#  ('001-03-169', 169, 0),
#  ('001-03-49740', 49740, 1),
#  ('001-03-46631', 46631, 1),
#  ('001-03-81420', 81420, 0),
#  ('001-03-89058', 89058, 0),
#  ('001-03-93383', 93383, 1),
#  ('001-03-66257', 66257, 1),
#  ('001-03-64358', 64358, 2),
#  ('001-03-15740', 15740, 0),
#  ('001-03-29117', 29117, 2),
#  ('001-03-65708', 65708, 2),
#  ('001-03-83988', 83988, 2),
#  ('001-03-73104', 73104, 0),
#  ('001-03-85582', 85582, 1),
#  ('001-03-90237', 90237, 0),
#  ('001-03-92945', 92945, 0),
#  ('001-04-8640', 8640, 1),
#  ('001-04-70583', 70583, 0),
#  ('001-04-77007', 77007, 1),
#  ('001-04-15766', 15766, 0),
#  ('001-04-77826', 77826, 0),
#  ('001-04-49819', 49819, 0),
#  ('001-04-8549', 8549, 0),
#  ('001-04-18189', 18189, 0),
#  ('001-04-48621', 48621, 2),
#  ('001-04-79021', 79021, 0),
#  ('001-04-64240', 64240, 2),
#  ('001-04-5375', 5375, 0),
#  ('001-04-37810', 37810, 1),
#  ('001-04-89084', 89084, 0),
#  ('001-04-91420', 91420, 1),
#  ('001-04-37162', 37162, 1),
#  ('001-04-59593', 59593, 2),
#  ('001-04-89753', 89753, 2),
#  ('001-04-83848', 83848, 1),
#  ('001-04-54546', 54546, 0),
#  ('001-04-85000', 85000, 0),
#  ('001-04-45173', 45173, 0),
#  ('001-04-89127', 89127, 1),
#  ('001-04-45715', 45715, 0),
#  ('001-04-64324', 64324, 0),
#  ('001-04-79350', 79350, 0),
#  ('001-04-81264', 81264, 0),
#  ('001-04-16805', 16805, 2),
#  ('001-04-1785', 1785, 0),
#  ('001-04-2525', 2525, 1),
#  ('001-05-50300', 50300, 0),
#  ('001-05-94170', 94170, 1),
#  ('001-05-2073', 2073, 1),
#  ('001-05-30398', 30398, 2),
#  ('001-05-14404', 14404, 1),
#  ('001-05-94610', 94610, 0),
#  ('001-05-94716', 94716, 2),
#  ('001-05-66097', 66097, 0),
#  ('001-05-62600', 62600, 1),
#  ('001-05-80817', 80817, 2),
#  ('001-05-77194', 77194, 1),
#  ('001-05-85438', 85438, 0),
#  ('001-05-91801', 91801, 2),
#  ('001-05-75095', 75095, 0),
#  ('001-05-85351', 85351, 0),
#  ('001-05-33260', 33260, 0),
#  ('001-05-76060', 76060, 0),
#  ('001-05-92989', 92989, 1),
#  ('001-05-60510', 60510, 2),
#  ('001-05-93015', 93015, 2),
#  ('001-05-15727', 15727, 1),
#  ('001-05-23738', 23738, 0),
#  ('001-05-94436', 94436, 0),
#  ('001-05-32576', 32576, 1),
#  ('001-05-92601', 92601, 0),
#  ('001-05-37431', 37431, 2),
#  ('001-05-66820', 66820, 0),
#  ('001-05-23424', 23424, 2),
#  ('001-05-79640', 79640, 2),
#  ('001-05-66735', 66735, 0),
#  ('001-06-39924', 39924, 0),
#  ('001-06-55311', 55311, 2),
#  ('001-06-81148', 81148, 0),
#  ('001-06-75999', 75999, 0),
#  ('001-06-19951', 19951, 0),
#  ('001-06-74996', 74996, 1),
#  ('001-06-79810', 79810, 2),
#  ('001-06-89566', 89566, 1),
#  ('001-06-78120', 78120, 0),
#  ('001-06-23875', 23875, 1),
#  ('001-06-13883', 13883, 0),
#  ('001-06-3252', 3252, 2),
#  ('001-06-6177', 6177, 0),
#  ('001-06-40768', 40768, 0),
#  ('001-06-9546', 9546, 2),
#  ('001-06-68965', 68965, 2),
#  ('001-06-74198', 74198, 1),
#  ('001-06-77409', 77409, 0),
#  ('001-06-77545', 77545, 0),
#  ('001-06-77888', 77888, 0),
#  ('001-06-36565', 36565, 0),
#  ('001-06-71490', 71490, 2),
#  ('001-06-45160', 45160, 2),
#  ('001-06-21568', 21568, 1),
#  ('001-06-65847', 65847, 2),
#  ('001-06-42618', 42618, 2),
#  ('001-06-77267', 77267, 1),
#  ('001-06-93058', 93058, 1),
#  ('001-06-97252', 97252, 0),
#  ('001-06-75833', 75833, 0),
#  ('001-07-30207', 30207, 2),
#  ('001-07-28760', 28760, 0),
#  ('001-07-30726', 30726, 0),
#  ('001-07-45946', 45946, 1),
#  ('001-07-54607', 54607, 0),
#  ('001-07-71967', 71967, 0),
#  ('001-07-93404', 93404, 2),
#  ('001-07-91247', 91247, 1),
#  ('001-07-47542', 47542, 0),
#  ('001-07-23474', 23474, 2),
#  ('001-07-77548', 77548, 0),
#  ('001-07-77538', 77538, 1),
#  ('001-07-71947', 71947, 0),
#  ('001-07-8376', 8376, 0),
#  ('001-07-57870', 57870, 1),
#  ('001-07-35891', 35891, 0),
#  ('001-07-31938', 31938, 2),
#  ('001-07-77686', 77686, 2),
#  ('001-07-81636', 81636, 0),
#  ('001-07-46791', 46791, 2),
#  ('001-07-71393', 71393, 2),
#  ('001-07-93267', 93267, 2),
#  ('001-07-78467', 78467, 0),
#  ('001-07-75348', 75348, 0),
#  ('001-07-33448', 33448, 0),
#  ('001-07-92529', 92529, 2),
#  ('001-07-81090', 81090, 1),
#  ('001-07-79530', 79530, 1),
#  ('001-07-82271', 82271, 0),
#  ('001-07-53746', 53746, 1),
#  ('002-01-77396', 77396, 1),
#  ('002-01-78278', 78278, 0),
#  ('002-01-80768', 80768, 0),
#  ('002-01-82723', 82723, 0),
#  ('002-01-85315', 85315, 0),
#  ('002-01-17693', 17693, 0),
#  ('002-01-23344', 23344, 1),
#  ('002-01-751', 751, 1),
#  ('002-01-32674', 32674, 2),
#  ('002-01-2957', 2957, 2),
#  ('002-01-31680', 31680, 1),
#  ('002-01-28310', 28310, 1),
#  ('002-01-11786', 11786, 1),
#  ('002-01-74092', 74092, 1),
#  ('002-01-73018', 73018, 0),
#  ('002-01-57806', 57806, 0),
#  ('002-01-78626', 78626, 1),
#  ('002-01-68008', 68008, 0),
#  ('002-01-70471', 70471, 2),
#  ('002-01-44938', 44938, 0),
#  ('002-01-30158', 30158, 1),
#  ('002-01-24105', 24105, 2),
#  ('002-01-76647', 76647, 1),
#  ('002-01-74564', 74564, 2),
#  ('002-01-32367', 32367, 0),
#  ('002-01-75447', 75447, 1),
#  ('002-01-71056', 71056, 1),
#  ('002-01-66527', 66527, 1),
#  ('002-01-10703', 10703, 0),
#  ('002-01-90059', 90059, 1),
#  ('002-02-25563', 25563, 2),
#  ('002-02-94928', 94928, 2),
#  ('002-02-74876', 74876, 2),
#  ('002-02-85215', 85215, 2),
#  ('002-02-63170', 63170, 0),
#  ('002-02-62958', 62958, 1),
#  ('002-02-78447', 78447, 2),
#  ('002-02-610', 610, 0),
#  ('002-02-16441', 16441, 1),
#  ('002-02-56787', 56787, 0),
#  ('002-02-6970', 6970, 1),
#  ('002-02-78289', 78289, 0),
#  ('002-02-52073', 52073, 2),
#  ('002-02-65644', 65644, 0),
#  ('002-02-79133', 79133, 2),
#  ('002-02-11077', 11077, 0),
#  ('002-02-63561', 63561, 2),
#  ('002-02-70765', 70765, 1),
#  ('002-02-89382', 89382, 1),
#  ('002-02-15540', 15540, 2),
#  ('002-02-87694', 87694, 1),
#  ('002-02-88255', 88255, 1),
#  ('002-02-38422', 38422, 2),
#  ('002-02-79571', 79571, 0),
#  ('002-02-92206', 92206, 0),
#  ('002-02-68592', 68592, 1),
#  ('002-02-85887', 85887, 0),
#  ('002-02-84672', 84672, 2),
#  ('002-02-45292', 45292, 1),
#  ('002-02-54887', 54887, 2),
#  ('002-03-73280', 73280, 1),
#  ('002-03-96200', 96200, 1),
#  ('002-03-63723', 63723, 1),
#  ('002-03-37576', 37576, 2),
#  ('002-03-86824', 86824, 0),
#  ('002-03-94592', 94592, 2),
#  ('002-03-98288', 98288, 0),
#  ('002-03-35531', 35531, 1),
#  ('002-03-94807', 94807, 1),
#  ('002-03-73912', 73912, 0),
#  ('002-03-74959', 74959, 1),
#  ('002-03-31736', 31736, 1),
#  ('002-03-34244', 34244, 1),
#  ('002-03-56252', 56252, 1),
#  ('002-03-21095', 21095, 0),
#  ('002-03-9709', 9709, 0),
#  ('002-03-19611', 19611, 2),
#  ('002-03-47695', 47695, 2),
#  ('002-03-82522', 82522, 2),
#  ('002-03-75762', 75762, 2),
#  ('002-03-90621', 90621, 0),
#  ('002-03-84186', 84186, 2),
#  ('002-03-75509', 75509, 1),
#  ('002-03-54294', 54294, 0),
#  ('002-03-54230', 54230, 2),
#  ('002-03-53388', 53388, 2),
#  ('002-03-22317', 22317, 1),
#  ('002-03-91552', 91552, 0),
#  ('002-03-31125', 31125, 2),
#  ('002-03-50169', 50169, 0),
#  ('002-04-62032', 62032, 0),
#  ('002-04-82914', 82914, 1),
#  ('002-04-74768', 74768, 0),
#  ('002-04-74729', 74729, 2),
#  ('002-04-85825', 85825, 0),
#  ('002-04-24400', 24400, 2),
#  ('002-04-89665', 89665, 1),
#  ('002-04-28979', 28979, 0),
#  ('002-04-67516', 67516, 2),
#  ('002-04-56002', 56002, 0),
#  ('002-04-92587', 92587, 0),
#  ('002-04-80061', 80061, 0),
#  ('002-04-76129', 76129, 0),
#  ('002-04-92800', 92800, 0),
#  ('002-04-84025', 84025, 2),
#  ('002-04-83946', 83946, 2),
#  ('002-04-91683', 91683, 1),
#  ('002-04-3099', 3099, 2),
#  ('002-04-2623', 2623, 0),
#  ('002-04-68315', 68315, 2),
#  ('002-04-62849', 62849, 2),
#  ('002-04-81273', 81273, 1),
#  ('002-04-43158', 43158, 0),
#  ('002-04-83880', 83880, 0),
#  ('002-04-92813', 92813, 1),
#  ('002-04-39074', 39074, 0),
#  ('002-04-84836', 84836, 2),
#  ('002-04-29050', 29050, 0),
#  ('002-04-86004', 86004, 2),
#  ('002-04-86190', 86190, 2),
#  ('002-05-58361', 58361, 2),
#  ('002-05-62381', 62381, 0),
#  ('002-05-90385', 90385, 0),
#  ('002-05-45234', 45234, 1),
#  ('002-05-54693', 54693, 1),
#  ('002-05-72438', 72438, 0),
#  ('002-05-20260', 20260, 0),
#  ('002-05-72101', 72101, 0),
#  ('002-05-83317', 83317, 0),
#  ('002-05-2878', 2878, 1),
#  ('002-05-59409', 59409, 2),
#  ('002-05-83520', 83520, 0),
#  ('002-05-74139', 74139, 2),
#  ('002-05-72681', 72681, 1),
#  ('002-05-69786', 69786, 2),
#  ('002-05-65016', 65016, 2),
#  ('002-05-69730', 69730, 0),
#  ('002-05-51609', 51609, 2),
#  ('002-05-1917', 1917, 2),
#  ('002-05-92263', 92263, 1),
#  ('002-05-71690', 71690, 0),
#  ('002-05-80967', 80967, 0),
#  ('002-05-44279', 44279, 1),
#  ('002-05-66843', 66843, 1),
#  ('002-05-66472', 66472, 2),
#  ('002-05-79585', 79585, 0),
#  ('002-05-87318', 87318, 0),
#  ('002-05-137', 137, 0),
#  ('002-05-66827', 66827, 1),
#  ('002-05-76786', 76786, 1),
#  ('002-06-81054', 81054, 2),
#  ('002-06-84163', 84163, 0),
#  ('002-06-80277', 80277, 2),
#  ('002-06-18884', 18884, 0),
#  ('002-06-64870', 64870, 0),
#  ('002-06-17149', 17149, 2),
#  ('002-06-19278', 19278, 0),
#  ('002-06-74282', 74282, 1),
#  ('002-06-79649', 79649, 2),
#  ('002-06-14608', 14608, 0),
#  ('002-06-91517', 91517, 2),
#  ('002-06-92053', 92053, 0),
#  ('002-06-61418', 61418, 1),
#  ('002-06-79861', 79861, 0),
#  ('002-06-90656', 90656, 2),
#  ('002-06-8942', 8942, 0),
#  ('002-06-83076', 83076, 0),
#  ('002-06-86122', 86122, 1),
#  ('002-06-98285', 98285, 1),
#  ('002-06-29979', 29979, 0),
#  ('002-06-70109', 70109, 1),
#  ('002-06-88382', 88382, 2),
#  ('002-06-88169', 88169, 0),
#  ('002-06-29407', 29407, 2),
#  ('002-06-21233', 21233, 2),
#  ('002-06-84302', 84302, 2),
#  ('002-06-85854', 85854, 0),
#  ('002-06-47330', 47330, 2),
#  ('002-06-10314', 10314, 1),
#  ('002-06-46530', 46530, 2),
#  ('002-07-60892', 60892, 2),
#  ('002-07-61708', 61708, 1),
#  ('002-07-76909', 76909, 0),
#  ('002-07-13287', 13287, 0),
#  ('002-07-26262', 26262, 0),
#  ('002-07-83812', 83812, 1),
#  ('002-07-14264', 14264, 2),
#  ('002-07-25284', 25284, 0),
#  ('002-07-74177', 74177, 0),
#  ('002-07-27007', 27007, 1),
#  ('002-07-92500', 92500, 0),
#  ('002-07-68721', 68721, 1),
#  ('002-07-50482', 50482, 2),
#  ('002-07-74513', 74513, 1),
#  ('002-07-85989', 85989, 0),
#  ('002-07-29560', 29560, 2),
#  ('002-07-79820', 79820, 1),
#  ('002-07-44703', 44703, 0),
#  ('002-07-93021', 93021, 2),
#  ('002-07-8955', 8955, 1),
#  ('002-07-40943', 40943, 1),
#  ('002-07-92354', 92354, 0),
#  ('002-07-67353', 67353, 0),
#  ('002-07-82488', 82488, 0),
#  ('002-07-94847', 94847, 2),
#  ('002-07-25162', 25162, 0),
#  ('002-07-21600', 21600, 2),
#  ('002-07-71898', 71898, 1),
#  ('002-07-71025', 71025, 2),
#  ('002-07-76977', 76977, 1),
#  ('003-01-5072', 5072, 2),
#  ('003-01-93189', 93189, 0),
#  ('003-01-14320', 14320, 1),
#  ('003-01-73716', 73716, 2),
#  ('003-01-80406', 80406, 1),
#  ('003-01-16639', 16639, 2),
#  ('003-01-81474', 81474, 2),
#  ('003-01-12389', 12389, 0),
#  ('003-01-75203', 75203, 0),
#  ('003-01-72850', 72850, 1),
#  ('003-01-62455', 62455, 0),
#  ('003-01-74865', 74865, 1),
#  ('003-01-16892', 16892, 0),
#  ('003-01-87625', 87625, 2),
#  ('003-01-74706', 74706, 2),
#  ('003-01-86587', 86587, 1),
#  ('003-01-82631', 82631, 1),
#  ('003-01-75940', 75940, 2),
#  ('003-01-85013', 85013, 2),
#  ('003-01-48990', 48990, 1),
#  ('003-01-92121', 92121, 0),
#  ('003-01-703', 703, 1),
#  ('003-01-60098', 60098, 2),
#  ('003-01-83541', 83541, 1),
#  ('003-01-35184', 35184, 1),
#  ('003-01-69384', 69384, 1),
#  ('003-01-48719', 48719, 1),
#  ('003-01-44977', 44977, 0),
#  ('003-01-94156', 94156, 0),
#  ('003-01-83589', 83589, 2),
#  ('003-02-98157', 98157, 2),
#  ('003-02-92576', 92576, 2),
#  ('003-02-82665', 82665, 1),
#  ('003-02-96545', 96545, 1),
#  ('003-02-93894', 93894, 0),
#  ('003-02-93141', 93141, 2),
#  ('003-02-21488', 21488, 1),
#  ('003-02-83587', 83587, 0),
#  ('003-02-15482', 15482, 1),
#  ('003-02-85365', 85365, 1),
#  ('003-02-63230', 63230, 2),
#  ('003-02-54092', 54092, 1),
#  ('003-02-54567', 54567, 0),
#  ('003-02-49958', 49958, 1),
#  ('003-02-8545', 8545, 1),
#  ('003-02-92286', 92286, 0),
#  ('003-02-30802', 30802, 0),
#  ('003-02-75941', 75941, 1),
#  ('003-02-80925', 80925, 1),
#  ('003-02-51088', 51088, 0),
#  ('003-02-9954', 9954, 2),
#  ('003-02-63513', 63513, 0),
#  ('003-02-71121', 71121, 1),
#  ('003-02-87453', 87453, 2),
#  ('003-02-53158', 53158, 0),
#  ('003-02-78939', 78939, 2),
#  ('003-02-37366', 37366, 2),
#  ('003-02-30573', 30573, 0),
#  ('003-02-11011', 11011, 0),
#  ('003-02-92219', 92219, 2),
#  ('003-03-8663', 8663, 2),
#  ('003-03-30347', 30347, 2),
#  ('003-03-50029', 50029, 1),
#  ('003-03-77279', 77279, 1),
#  ('003-03-22581', 22581, 2),
#  ('003-03-94361', 94361, 1),
#  ('003-03-75935', 75935, 0),
#  ('003-03-89943', 89943, 1),
#  ('003-03-80641', 80641, 2),
#  ('003-03-60774', 60774, 2),
#  ('003-03-47986', 47986, 0),
#  ('003-03-33986', 33986, 1),
#  ('003-03-79924', 79924, 2),
#  ('003-03-62233', 62233, 0),
#  ('003-03-47416', 47416, 2),
#  ('003-03-42254', 42254, 0),
#  ('003-03-93433', 93433, 0),
#  ('003-03-29877', 29877, 0),
#  ('003-03-29725', 29725, 0),
#  ('003-03-67903', 67903, 2),
#  ('003-03-49521', 49521, 2),
#  ('003-03-89865', 89865, 2),
#  ('003-03-61523', 61523, 1),
#  ('003-03-88397', 88397, 2),
#  ('003-03-585', 585, 1),
#  ('003-03-4289', 4289, 2),
#  ('003-03-83768', 83768, 1),
#  ('003-03-23406', 23406, 1),
#  ('003-03-88784', 88784, 2),
#  ('003-03-84188', 84188, 0),
#  ('003-04-29840', 29840, 1),
#  ('003-04-91369', 91369, 1),
#  ('003-04-96337', 96337, 0),
#  ('003-04-86459', 86459, 1),
#  ('003-04-43759', 43759, 1),
#  ('003-04-71916', 71916, 2),
#  ('003-04-58777', 58777, 1),
#  ('003-04-81893', 81893, 1),
#  ('003-04-83274', 83274, 2),
#  ('003-04-61595', 61595, 1),
#  ('003-04-1140', 1140, 0),
#  ('003-04-76517', 76517, 0),
#  ('003-04-76262', 76262, 0),
#  ('003-04-92411', 92411, 2),
#  ('003-04-93305', 93305, 1),
#  ('003-04-38611', 38611, 2),
#  ('003-04-12086', 12086, 1),
#  ('003-04-81040', 81040, 1),
#  ('003-04-93911', 93911, 1),
#  ('003-04-42551', 42551, 0),
#  ('003-04-74259', 74259, 1),
#  ('003-04-47083', 47083, 2),
#  ('003-04-84159', 84159, 1),
#  ('003-04-77799', 77799, 1),
#  ('003-04-37228', 37228, 2),
#  ('003-04-896', 896, 1),
#  ('003-04-66620', 66620, 1),
#  ('003-04-89810', 89810, 1),
#  ('003-04-24076', 24076, 1),
#  ('003-04-82612', 82612, 1),
#  ('003-05-43380', 43380, 0),
#  ('003-05-95903', 95903, 1),
#  ('003-05-88144', 88144, 2),
#  ('003-05-4927', 4927, 1),
#  ('003-05-70504', 70504, 2),
#  ('003-05-71488', 71488, 2),
#  ('003-05-3502', 3502, 0),
#  ('003-05-88524', 88524, 1),
#  ('003-05-6624', 6624, 2),
#  ('003-05-87301', 87301, 1),
#  ('003-05-76134', 76134, 1),
#  ('003-05-53787', 53787, 2),
#  ('003-05-83950', 83950, 0),
#  ('003-05-44593', 44593, 1),
#  ('003-05-65911', 65911, 0),
#  ('003-05-7090', 7090, 1),
#  ('003-05-79993', 79993, 0),
#  ('003-05-70856', 70856, 1),
#  ('003-05-82196', 82196, 1),
#  ('003-05-91787', 91787, 0),
#  ('003-05-20314', 20314, 0),
#  ('003-05-73755', 73755, 2),
#  ('003-05-93635', 93635, 0),
#  ('003-05-56286', 56286, 2),
#  ('003-05-10052', 10052, 1),
#  ('003-05-61679', 61679, 0),
#  ('003-05-83638', 83638, 1),
#  ('003-05-83769', 83769, 2),
#  ('003-05-75405', 75405, 1),
#  ('003-05-66786', 66786, 1),
#  ('003-06-91863', 91863, 0),
#  ('003-06-67630', 67630, 1),
#  ('003-06-76628', 76628, 0),
#  ('003-06-41119', 41119, 1),
#  ('003-06-75116', 75116, 1),
#  ('003-06-83423', 83423, 2),
#  ('003-06-79969', 79969, 0),
#  ('003-06-74000', 74000, 0),
#  ('003-06-89499', 89499, 1),
#  ('003-06-90525', 90525, 2),
#  ('003-06-82936', 82936, 0),
#  ('003-06-72422', 72422, 0),
#  ('003-06-26766', 26766, 0),
#  ('003-06-23194', 23194, 2),
#  ('003-06-94631', 94631, 2),
#  ('003-06-83123', 83123, 1),
#  ('003-06-46146', 46146, 1),
#  ('003-06-91001', 91001, 0),
#  ('003-06-60183', 60183, 0),
#  ('003-06-83307', 83307, 0),
#  ('003-06-18469', 18469, 2),
#  ('003-06-90084', 90084, 0),
#  ('003-06-63975', 63975, 0),
#  ('003-06-74321', 74321, 2),
#  ('003-06-88567', 88567, 1),
#  ('003-06-1812', 1812, 0),
#  ('003-06-59001', 59001, 2),
#  ('003-06-92460', 92460, 1),
#  ('003-06-418', 418, 0),
#  ('003-06-79452', 79452, 2),
#  ('003-07-77157', 77157, 1),
#  ('003-07-88061', 88061, 1),
#  ('003-07-72682', 72682, 0),
#  ('003-07-76333', 76333, 1),
#  ('003-07-93281', 93281, 2),
#  ('003-07-34361', 34361, 0),
#  ('003-07-85264', 85264, 1),
#  ('003-07-90758', 90758, 2),
#  ('003-07-69503', 69503, 2),
#  ('003-07-89694', 89694, 2),
#  ('003-07-62536', 62536, 0),
#  ('003-07-73673', 73673, 2),
#  ('003-07-11072', 11072, 1),
#  ('003-07-78373', 78373, 1),
#  ('003-07-71111', 71111, 0),
#  ('003-07-91585', 91585, 2),
#  ('003-07-89831', 89831, 1),
#  ('003-07-45445', 45445, 2),
#  ('003-07-93264', 93264, 1),
#  ('003-07-91460', 91460, 0),
#  ('003-07-58688', 58688, 0),
#  ('003-07-15334', 15334, 2),
#  ('003-07-92172', 92172, 1),
#  ('003-07-79830', 79830, 0),
#  ('003-07-79373', 79373, 1),
#  ('003-07-58036', 58036, 1),
#  ('003-07-77170', 77170, 1),
#  ('003-07-67512', 67512, 0),
#  ('003-07-85677', 85677, 1),
#  ('003-07-42744', 42744, 0),
#  ('004-01-56893', 56893, 2),
#  ('004-01-58572', 58572, 0),
#  ('004-01-75932', 75932, 0),
#  ('004-01-88473', 88473, 0),
#  ('004-01-78916', 78916, 2),
#  ('004-01-72973', 72973, 0),
#  ('004-01-50834', 50834, 1),
#  ('004-01-91024', 91024, 2),
#  ('004-01-64960', 64960, 0),
#  ('004-01-50913', 50913, 1),
#  ('004-01-58160', 58160, 2),
#  ('004-01-83443', 83443, 2),
#  ('004-01-91099', 91099, 0),
#  ('004-01-98077', 98077, 1),
#  ('004-01-80797', 80797, 2),
#  ('004-01-62796', 62796, 0),
#  ('004-01-69717', 69717, 1),
#  ('004-01-7', 7, 2),
#  ('004-01-71557', 71557, 0),
#  ('004-01-63306', 63306, 2),
#  ('004-01-36154', 36154, 1),
#  ('004-01-86424', 86424, 2),
#  ('004-01-79697', 79697, 0),
#  ('004-01-92313', 92313, 2),
#  ('004-01-74253', 74253, 2),
#  ('004-01-64340', 64340, 2),
#  ('004-01-65199', 65199, 0),
#  ('004-01-91190', 91190, 0),
#  ('004-01-16017', 16017, 1),
#  ('004-01-87064', 87064, 2),
#  ('004-02-74042', 74042, 1),
#  ('004-02-47187', 47187, 1),
#  ('004-02-74848', 74848, 0),
#  ('004-02-74344', 74344, 2),
#  ('004-02-66525', 66525, 0),
#  ('004-02-91158', 91158, 2),
#  ('004-02-68979', 68979, 0),
#  ('004-02-19699', 19699, 1),
#  ('004-02-92531', 92531, 2),
#  ('004-02-46137', 46137, 0),
#  ('004-02-92021', 92021, 1),
#  ('004-02-85007', 85007, 0),
#  ('004-02-11794', 11794, 0),
#  ('004-02-19077', 19077, 0),
#  ('004-02-66310', 66310, 0),
#  ('004-02-27961', 27961, 1),
#  ('004-02-88986', 88986, 0),
#  ('004-02-76208', 76208, 0),
#  ('004-02-80270', 80270, 2),
#  ('004-02-4472', 4472, 0),
#  ('004-02-75551', 75551, 1),
#  ('004-02-58435', 58435, 2),
#  ('004-02-87929', 87929, 0),
#  ('004-02-93420', 93420, 2),
#  ('004-02-34837', 34837, 1),
#  ('004-02-86955', 86955, 0),
#  ('004-02-92058', 92058, 1),
#  ('004-02-79525', 79525, 2),
#  ('004-02-89973', 89973, 1),
#  ('004-02-9060', 9060, 0),
#  ('004-03-13603', 13603, 0),
#  ('004-03-42232', 42232, 2),
#  ('004-03-78928', 78928, 2),
#  ('004-03-48656', 48656, 0),
#  ('004-03-88318', 88318, 1),
#  ('004-03-59155', 59155, 1),
#  ('004-03-26680', 26680, 0),
#  ('004-03-25072', 25072, 1),
#  ('004-03-719', 719, 2),
#  ('004-03-73295', 73295, 2),
#  ('004-03-68114', 68114, 2),
#  ('004-03-82851', 82851, 0),
#  ('004-03-69766', 69766, 0),
#  ('004-03-25150', 25150, 1),
#  ('004-03-86679', 86679, 0),
#  ('004-03-5520', 5520, 2),
#  ('004-03-44139', 44139, 1),
#  ('004-03-82289', 82289, 1),
#  ('004-03-78214', 78214, 1),
#  ('004-03-61166', 61166, 1),
#  ('004-03-61858', 61858, 2),
#  ('004-03-64999', 64999, 0),
#  ('004-03-94148', 94148, 2),
#  ('004-03-3088', 3088, 0),
#  ('004-03-64519', 64519, 1),
#  ('004-03-58171', 58171, 2),
#  ('004-03-71655', 71655, 2),
#  ('004-03-21324', 21324, 2),
#  ('004-03-78157', 78157, 2),
#  ('004-03-90296', 90296, 1),
#  ('004-04-65660', 65660, 0),
#  ('004-04-76560', 76560, 1),
#  ('004-04-90068', 90068, 2),
#  ('004-04-43616', 43616, 0),
#  ('004-04-84185', 84185, 1),
#  ('004-04-61987', 61987, 0),
#  ('004-04-21500', 21500, 0),
#  ('004-04-55712', 55712, 0),
#  ('004-04-36653', 36653, 0),
#  ('004-04-63292', 63292, 1),
#  ('004-04-49950', 49950, 2),
#  ('004-04-85510', 85510, 1),
#  ('004-04-9198', 9198, 0),
#  ('004-04-81823', 81823, 0),
#  ('004-04-93352', 93352, 1),
#  ('004-04-87327', 87327, 0),
#  ('004-04-76823', 76823, 0),
#  ('004-04-16142', 16142, 0),
#  ('004-04-95761', 95761, 2),
#  ('004-04-89769', 89769, 2),
#  ('004-04-73738', 73738, 0),
#  ('004-04-99690', 99690, 0),
#  ('004-04-39020', 39020, 0),
#  ('004-04-42839', 42839, 1),
#  ('004-04-2175', 2175, 0),
#  ('004-04-84283', 84283, 2),
#  ('004-04-74755', 74755, 1),
#  ('004-04-61380', 61380, 1),
#  ('004-04-80292', 80292, 2),
#  ('004-04-15824', 15824, 1),
#  ('004-05-66915', 66915, 1),
#  ('004-05-88846', 88846, 0),
#  ('004-05-44552', 44552, 2),
#  ('004-05-93343', 93343, 2),
#  ('004-05-64591', 64591, 0),
#  ('004-05-41891', 41891, 1),
#  ('004-05-82993', 82993, 2),
#  ('004-05-55151', 55151, 1),
#  ('004-05-78864', 78864, 0),
#  ('004-05-93790', 93790, 1),
#  ('004-05-78179', 78179, 2),
#  ('004-05-45498', 45498, 2),
#  ('004-05-77741', 77741, 0),
#  ('004-05-7340', 7340, 1),
#  ('004-05-87529', 87529, 0),
#  ('004-05-86172', 86172, 1),
#  ('004-05-55099', 55099, 1),
#  ('004-05-88838', 88838, 0),
#  ('004-05-91731', 91731, 0),
#  ('004-05-80540', 80540, 1),
#  ('004-05-80432', 80432, 1),
#  ('004-05-23410', 23410, 1),
#  ('004-05-22557', 22557, 0),
#  ('004-05-5740', 5740, 0),
#  ('004-05-37980', 37980, 2),
#  ('004-05-23986', 23986, 1),
#  ('004-05-4528', 4528, 2),
#  ('004-05-64372', 64372, 1),
#  ('004-05-73021', 73021, 1),
#  ('004-05-77735', 77735, 0),
#  ('004-06-88415', 88415, 1),
#  ('004-06-62223', 62223, 0),
#  ('004-06-82558', 82558, 0),
#  ('004-06-35956', 35956, 2),
#  ('004-06-52208', 52208, 2),
#  ('004-06-14239', 14239, 1),
#  ('004-06-10276', 10276, 1),
#  ('004-06-73356', 73356, 0),
#  ('004-06-75710', 75710, 0),
#  ('004-06-19597', 19597, 0),
#  ('004-06-95373', 95373, 1),
#  ('004-06-8371', 8371, 0),
#  ('004-06-84889', 84889, 1),
#  ('004-06-94326', 94326, 1),
#  ('004-06-15688', 15688, 1),
#  ('004-06-18709', 18709, 2),
#  ('004-06-94106', 94106, 1),
#  ('004-06-63361', 63361, 0),
#  ('004-06-37078', 37078, 1),
#  ('004-06-44358', 44358, 0),
#  ('004-06-86676', 86676, 0),
#  ('004-06-92907', 92907, 1),
#  ('004-06-65545', 65545, 2),
#  ('004-06-9242', 9242, 1),
#  ('004-06-38739', 38739, 2),
#  ('004-06-19594', 19594, 1),
#  ('004-06-42574', 42574, 2),
#  ('004-06-61342', 61342, 1),
#  ('004-06-66676', 66676, 2),
#  ('004-06-65309', 65309, 1),
#  ('004-07-73856', 73856, 2),
#  ('004-07-94150', 94150, 2),
#  ('004-07-43224', 43224, 1),
#  ('004-07-2078', 2078, 2),
#  ('004-07-60276', 60276, 0),
#  ('004-07-52312', 52312, 2),
#  ('004-07-74200', 74200, 0),
#  ('004-07-77254', 77254, 0),
#  ('004-07-42099', 42099, 2),
#  ('004-07-75490', 75490, 2),
#  ('004-07-84506', 84506, 1),
#  ('004-07-77356', 77356, 0),
#  ('004-07-59733', 59733, 2),
#  ('004-07-9735', 9735, 1),
#  ('004-07-86780', 86780, 2),
#  ('004-07-82900', 82900, 0),
#  ('004-07-93360', 93360, 1),
#  ('004-07-93208', 93208, 1),
#  ('004-07-93512', 93512, 0),
#  ('004-07-66690', 66690, 0),
#  ('004-07-33108', 33108, 2),
#  ('004-07-72193', 72193, 2),
#  ('004-07-92336', 92336, 0),
#  ('004-07-89717', 89717, 0),
#  ('004-07-80611', 80611, 1),
#  ('004-07-82119', 82119, 2),
#  ('004-07-46662', 46662, 0),
#  ('004-07-73299', 73299, 1),
#  ('004-07-83487', 83487, 0),
#  ('004-07-93594', 93594, 0),
#  ('005-01-87810', 87810, 0),
#  ('005-01-22880', 22880, 1),
#  ('005-01-79642', 79642, 0),
#  ('005-01-80892', 80892, 1),
#  ('005-01-27155', 27155, 1),
#  ('005-01-76929', 76929, 0),
#  ('005-01-35633', 35633, 2),
#  ('005-01-83590', 83590, 2),
#  ('005-01-26377', 26377, 2),
#  ('005-01-45059', 45059, 2),
#  ('005-01-71896', 71896, 2),
#  ('005-01-51427', 51427, 1),
#  ('005-01-29856', 29856, 1),
#  ('005-01-27000', 27000, 0),
#  ('005-01-34230', 34230, 0),
#  ('005-01-38451', 38451, 1),
#  ('005-01-56026', 56026, 0),
#  ('005-01-71737', 71737, 0),
#  ('005-01-67466', 67466, 0),
#  ('005-01-72794', 72794, 2),
#  ('005-01-60986', 60986, 1),
#  ('005-01-11870', 11870, 1),
#  ('005-01-82600', 82600, 1),
#  ('005-01-65534', 65534, 1),
#  ('005-01-94676', 94676, 2),
#  ('005-01-72972', 72972, 0),
#  ('005-01-75174', 75174, 0),
#  ('005-01-74293', 74293, 0),
#  ('005-01-50151', 50151, 2),
#  ('005-01-79217', 79217, 2),
#  ('005-02-84492', 84492, 2),
#  ('005-02-26618', 26618, 2),
#  ('005-02-89602', 89602, 2),
#  ('005-02-80698', 80698, 2),
#  ('005-02-50357', 50357, 1),
#  ('005-02-42401', 42401, 1),
#  ('005-02-78236', 78236, 1),
#  ('005-02-57523', 57523, 1),
#  ('005-02-23446', 23446, 1),
#  ('005-02-80163', 80163, 0),
#  ('005-02-69507', 69507, 1),
#  ('005-02-94586', 94586, 0),
#  ('005-02-33122', 33122, 1),
#  ('005-02-8921', 8921, 2),
#  ('005-02-53396', 53396, 1),
#  ('005-02-5587', 5587, 0),
#  ('005-02-90216', 90216, 0),
#  ('005-02-6251', 6251, 0),
#  ('005-02-79108', 79108, 0),
#  ('005-02-82080', 82080, 0),
#  ('005-02-73310', 73310, 0),
#  ('005-02-9366', 9366, 2),
#  ('005-02-9331', 9331, 0),
#  ('005-02-26024', 26024, 1),
#  ('005-02-6850', 6850, 2),
#  ('005-02-47303', 47303, 0),
#  ('005-02-91168', 91168, 2),
#  ('005-02-9495', 9495, 0),
#  ('005-02-74008', 74008, 1),
#  ('005-02-66264', 66264, 1),
#  ('005-03-93187', 93187, 2),
#  ('005-03-77252', 77252, 2),
#  ('005-03-40748', 40748, 1),
#  ('005-03-61741', 61741, 1),
#  ('005-03-68421', 68421, 2),
#  ('005-03-72433', 72433, 1),
#  ('005-03-78863', 78863, 2),
#  ('005-03-93588', 93588, 0),
#  ('005-03-94184', 94184, 2),
#  ('005-03-74357', 74357, 1),
#  ('005-03-48441', 48441, 1),
#  ('005-03-81926', 81926, 1),
#  ('005-03-20731', 20731, 2),
#  ('005-03-81334', 81334, 0),
#  ('005-03-94059', 94059, 1),
#  ('005-03-45262', 45262, 0),
#  ('005-03-91301', 91301, 0),
#  ('005-03-86523', 86523, 0),
#  ('005-03-86250', 86250, 2),
#  ('005-03-94513', 94513, 0),
#  ('005-03-20695', 20695, 1),
#  ('005-03-1018', 1018, 1),
#  ('005-03-72285', 72285, 2),
#  ('005-03-94473', 94473, 0),
#  ('005-03-52558', 52558, 0),
#  ('005-03-29258', 29258, 2),
#  ('005-03-23957', 23957, 2),
#  ('005-03-34809', 34809, 2),
#  ('005-03-82337', 82337, 1),
#  ('005-03-2629', 2629, 2),
#  ('005-04-92186', 92186, 2),
#  ('005-04-71573', 71573, 0),
#  ('005-04-83787', 83787, 0),
#  ('005-04-25527', 25527, 1),
#  ('005-04-88387', 88387, 0),
#  ('005-04-94018', 94018, 1),
#  ('005-04-40096', 40096, 0),
#  ('005-04-82765', 82765, 0),
#  ('005-04-2214', 2214, 0),
#  ('005-04-7633', 7633, 0),
#  ('005-04-91278', 91278, 2),
#  ('005-04-23712', 23712, 1),
#  ('005-04-84773', 84773, 2),
#  ('005-04-72930', 72930, 2),
#  ('005-04-24933', 24933, 2),
#  ('005-04-40720', 40720, 0),
#  ('005-04-17501', 17501, 2),
#  ('005-04-8153', 8153, 0),
#  ('005-04-65591', 65591, 1),
#  ('005-04-87344', 87344, 2),
#  ('005-04-81132', 81132, 0),
#  ('005-04-88495', 88495, 2),
#  ('005-04-92731', 92731, 0),
#  ('005-04-84880', 84880, 2),
#  ('005-04-48950', 48950, 0),
#  ('005-04-93224', 93224, 1),
#  ('005-04-29736', 29736, 2),
#  ('005-04-72994', 72994, 0),
#  ('005-04-87142', 87142, 0),
#  ('005-04-52186', 52186, 1),
#  ('005-05-23367', 23367, 2),
#  ('005-05-11883', 11883, 2),
#  ('005-05-22077', 22077, 2),
#  ('005-05-71010', 71010, 1),
#  ('005-05-89707', 89707, 2),
#  ('005-05-88552', 88552, 0),
#  ('005-05-64753', 64753, 0),
#  ('005-05-13983', 13983, 0),
#  ('005-05-29744', 29744, 1),
#  ('005-05-72405', 72405, 1),
#  ('005-05-45644', 45644, 0),
#  ('005-05-93984', 93984, 0),
#  ('005-05-91010', 91010, 0),
#  ('005-05-22542', 22542, 0),
#  ('005-05-64305', 64305, 0),
#  ('005-05-67199', 67199, 2),
#  ('005-05-66413', 66413, 2),
#  ('005-05-31714', 31714, 2),
#  ('005-05-4654', 4654, 1),
#  ('005-05-71583', 71583, 1),
#  ('005-05-49534', 49534, 1),
#  ('005-05-19858', 19858, 0),
#  ('005-05-83025', 83025, 0),
#  ('005-05-32194', 32194, 1),
#  ('005-05-56957', 56957, 0),
#  ('005-05-90727', 90727, 1),
#  ('005-05-92544', 92544, 1),
#  ('005-05-30374', 30374, 1),
#  ('005-05-49238', 49238, 2),
#  ('005-05-2754', 2754, 0),
#  ('005-06-51437', 51437, 1),
#  ('005-06-49522', 49522, 1),
#  ('005-06-90713', 90713, 2),
#  ('005-06-94407', 94407, 2),
#  ('005-06-1236', 1236, 2),
#  ('005-06-48662', 48662, 2),
#  ('005-06-71970', 71970, 1),
#  ('005-06-78651', 78651, 0),
#  ('005-06-14953', 14953, 0),
#  ('005-06-40666', 40666, 2),
#  ...)
